# %%
i = 1
while i <= 100:
    n = i
    found_seven = False
    while n > 0:
        if n % 10 == 7:
            found_seven = True
            break
        n //= 10
    if found_seven:
        print(i)
    i += 1
# Out:
# 7
# 17
# 27
# 37
# 47
# 57
# 67
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 77
# 78
# 79
# 87
# 97
